# %% [markdown]
# # Průvodce API pro začátečníky
#
# API (Application Programming Interface) umožňuje počítačům, aby spolu navzájem komunikovaly. Pro odesílání a přijímání dat z API použijeme knihovnu requests v Pythonu.
#
# ## Nastavení
#
# Nejprve nainstalujte knihovnu requests `pip install requests`

# %% [markdown]
# ## GET požadavek
#
# Požadavek GET se používá k vyžádání dat ze zadaného zdroje (resource).

# %%
import requests

response = requests.get('https://httpbin.org/get')
print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6890fc64-3e4936b840904f9e7976c82b"
#   },
#   "origin": "86.49.255.7",
#   "url": "https://httpbin.org/get"
# }

# %%
# http://open-notify.org/Open-Notify-API/ISS-Location-Now/

import requests

response = requests.get('http://api.open-notify.org/iss-now.json')
print(response.status_code)
print(response.text)
# Out:
# 200
# {"timestamp": 1754332997, "message": "success", "iss_position": {"longitude": "45.6841", "latitude": "-35.1260"}}

# %% [markdown]
# ## POST požadavek
#
# Požadavek POST se používá k odesílání dat na server za účelem vytvoření/aktualizace zdroje (resource).

# %%
import requests

data = {'key': 'value'}
response = requests.post('https://httpbin.org/post', data=data)
print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6890fc54-03e0bc775ca65a6c0f36b01d"
#   },
#   "json": null,
#   "origin": "86.49.255.7",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# ## Úkol: Zobrazení posledních 5 poloh Mezinárodní vesmírné stanice (ISS)

# %% [markdown]
# Pro kontrolu polohy ISS se můžeme podívat na stránky [ESA](https://www.esa.int/Science_Exploration/Human_and_Robotic_Exploration/International_Space_Station/Where_is_the_International_Space_Station)
